# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahularc21/Machine-Learning/blob/main/PivotTables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Pivot Tables**

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    516     14   John  January      Q1
# 1  2023-01-02       B   West    750     20   Mary  January      Q1
# 2  2023-01-03       C  North    414     60    Bob  January      Q1
# 3  2023-01-04       D  South    976     22  Alice  January      Q1
# 4  2023-01-05       A   East    309     91   John  January      Q1
# 5  2023-01-06       B   West    399     44   Mary  January      Q1
# 6  2023-01-07       C  North    909     87    Bob  January      Q1
# 7  2023-01-08       D  South    180     49  Alice  January      Q1
# 8  2023-01-09       A   East    227     90   John  January      Q1
# 9  2023-01-10       B   West    225     83   Mary  January      Q1
# 10 2023-01-11       C  North    426     60    Bob  January      Q1
# 11 2023-01-12       D  South    935     31  Alice  January      Q1
# 12 2023-01-13       A   East    276     69   John  January      Q1
# ...

# %%
pd.pivot_table(df,values='Sales',index='Region',columns='Product',aggfunc='sum')
# Out:
# Product       A       B       C       D
# Region
# East     2013.0     NaN     NaN     NaN
# North       NaN     NaN  3227.0     NaN
# South       NaN     NaN     NaN  3417.0
# West        NaN  3031.0     NaN     NaN

# %%
pd.pivot_table(df,values=['Sales','Units'],index='Region',columns='Product',aggfunc='sum')
#agg function ke liye pivot table
# Out:
#           Sales                          Units
# Product       A       B       C       D      A      B      C      D
# Region
# East     2013.0     NaN     NaN     NaN  329.0    NaN    NaN    NaN
# North       NaN     NaN  3227.0     NaN    NaN    NaN  345.0    NaN
# South       NaN     NaN     NaN  3417.0    NaN    NaN    NaN  252.0
# West        NaN  3031.0     NaN     NaN    NaN  269.0    NaN    NaN

# %% [markdown]
# **Cross Tabs**

# %%
pd.crosstab(df['Region'],df['Product'])    #count aarhaaa...
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
