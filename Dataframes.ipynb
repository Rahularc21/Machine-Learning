# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahularc21/Machine-Learning/blob/main/Dataframes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Creating DataFrames**

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]

# %%
pd.DataFrame(data_list)  #column names ni aaye is baar...
# Out:
#        0   1         2      3
# 0   John  28  New York  65000
# 1   Anna  34     Paris  70000
# 2  Peter  29    Berlin  62000
# 3  Linda  42    London  85000

# %%
col=['Name','Age','City','Salary']

# %%
df2=pd.DataFrame(data_list,columns=col)

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# **Selection and Indexing of Columns**

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2['Name']
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: object

# %%
df2[['Name','City']]   #Multiple Columns
# Out:
#     Name      City
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %% [markdown]
# **Creating new Columns**

# %%
df2['Designation']=['teacher','doctor','Engineer','teacher']

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000     teacher
# 1   Anna   34     Paris   70000      doctor
# 2  Peter   29    Berlin   62000    Engineer
# 3  Linda   42    London   85000     teacher

# %% [markdown]
# **Removing Columns**

# %%
df2.drop("Designation",axis=1,inplace=True)    #axis=1 na likheege to rows me dekhegaa..... inplace for permanent changes...

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2.drop(['City','Salary'],axis=1)   #removing multiple columns...
# Out:
#     Name  Age
# 0   John   28
# 1   Anna   34
# 2  Peter   29
# 3  Linda   42

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# **Selecting Rows**

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
# df2[0]     error

# %%
df2.loc[[0,1]]  #for selecting rows
# Out:
#    Name  Age      City  Salary
# 0  John   28  New York   65000
# 1  Anna   34     Paris   70000

# %%
df2.iloc[[0,1]] #with indexes
# Out:
#    Name  Age      City  Salary
# 0  John   28  New York   65000
# 1  Anna   34     Paris   70000

# %% [markdown]
# **Selecting Subsets of Rows and Columns**

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2.loc[[0,1]][['City','Salary']]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000

# %%
df2.loc[[2,3]][['Name','Age']]
# Out:
#     Name  Age
# 2  Peter   29
# 3  Linda   42

# %% [markdown]
# **Conditional Selection**

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#want to see those people whose age is above 30
df2[df2['Age']>30]
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London   85000

# %%
#want to see those people whose age is above 30 and from paris
df2[(df2['Age']>30) & (df2['City']=='Paris')]
# Out:
#    Name  Age   City  Salary
# 1  Anna   34  Paris   70000
